# %% [markdown]
# # vectors
#
# # A vector is simply an ordered collection of numbers.
#
# - Those numbers together describe something.
#
# - Sometimes that "something" is:
#
# Position
# Direction
# Temperature
# Color
# Sound
# Image
# Sentence
# User
# Product

# %%
import numpy as np

python_list = [2, 5, 8]

numpy_vector = np.array([2, 5, 8])

print(type(python_list))
print(type(numpy_vector))

# %% [markdown]
# ## Python Lists vs NumPy Vectors
#
# ### Why use NumPy?
#
# - Because vectors are mathematical objects.
# - Lists are general containers.
# - NumPy knows mathematics.
#
# ### Vectors are ordered.
#
# ### shape is for the values on 1-axis

# %% [markdown]
# Suppose we want to identify houses.
#
# Each house has
#
# Bedrooms
#
# Bathrooms
#
# Area
#
# Age
#
# We create
#
# house = np.array([
#     3,
#     2,
#     1400,
#     8
# ])

# %%
#images are vectors they only see the pixels


pixels = np.array([
    255,
    120,
    90,
    30
])
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
