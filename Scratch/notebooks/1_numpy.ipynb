# %%
import numpy as np
print(np.__version__)

# %%
python_list=[1,2,3,4,5]
python_array =np.array([1, 2, 3, 4, 5])

print(type(python_list))
print(type(python_array))

# %% [markdown]
# # ai can use 100's and 1000's of dimensions, not a 1D, so we use N-dimensional arrays.

# %%
arr = np.array([1,2,3, 4,5])
print(arr)

print(arr.shape)

# %% [markdown]
# # arr.shape is (4,) not 4

# %%
print(arr.dtype) 
# type of data-> based on it bits allocation

print(arr.itemsize) # no of items

print(arr.nbytes) #no of bytes

print(arr.ndim)

print(len(arr))

#len != shape != ndim
